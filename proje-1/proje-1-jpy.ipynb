# %%
from sklearn.datasets import load_iris
import pandas as pd

# Iris veri kümesini yükleyelim
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target

# İlk birkaç satırı görüntüleyelim
df.head()
# Out:
# <ipython-input-1-fadc1e04f14b>:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Temel istatistikler
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
# Sınıf dağılımı (target)
df['target'].value_counts()
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Sepal özelliklerinin dağılımı
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(df.iloc[:, 0], df.iloc[:, 1], c=df['target'])
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Sepal Length vs Sepal Width')

plt.subplot(1, 2, 2)
plt.scatter(df.iloc[:, 2], df.iloc[:, 3], c=df['target'])
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('Petal Length vs Petal Width')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Sınıflara göre sepal length dağılımı
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
df.boxplot(column='sepal length (cm)', by='target')
plt.title('Sınıflara Göre Sepal Length Dağılımı')
plt.suptitle('')  # Üst başlığı kaldırmak için suptitle'a boş değer atıyoruz

# Sınıflara göre sepal width dağılımı
plt.subplot(2, 2, 2)
df.boxplot(column='sepal width (cm)', by='target')
plt.title('Sınıflara Göre Sepal Width Dağılımı')
plt.suptitle('')

# Sınıflara göre petal length dağılımı
plt.subplot(2, 2, 3)
df.boxplot(column='petal length (cm)', by='target')
plt.title('Sınıflara Göre Petal Length Dağılımı')
plt.suptitle('')

# Sınıflara göre petal width dağılımı
plt.subplot(2, 2, 4)
df.boxplot(column='petal width (cm)', by='target')
plt.title('Sınıflara Göre Petal Width Dağılımı')
plt.suptitle('')

plt.tight_layout()
plt.show()

# %%
plt.figure()
df.boxplot(column='sepal length (cm)', by='target')
plt.title('Sınıflara Göre Sepal Length Dağılımı')
plt.suptitle('')
plt.show()

# %%
plt.figure()
df.boxplot(column='sepal width (cm)', by='target')
plt.title('Sınıflara Göre Sepal Width Dağılımı')
plt.suptitle('')
plt.show()

# %%
plt.figure()
df.boxplot(column='petal length (cm)', by='target')
plt.title('Sınıflara Göre Petal Length Dağılımı')
plt.suptitle('')
plt.show()

# %%
plt.figure()
df.boxplot(column='petal width (cm)', by='target')
plt.title('Sınıflara Göre Petal Width Dağılımı')
plt.suptitle('')
plt.show()

# %% [markdown]
# # Rapor
#
# ## Giriş
# Bu analizde Iris veri kümesini kullanarak temel veri analizi ve görselleştirme yapılmıştır.
#
# ## Veri Temizleme
# Veri kümesi oldukça temiz olup ek bir temizleme işlemi gerektirmemiştir.
#
# ## Keşifsel Veri Analizi (EDA)
# Veri kümesinin temel istatistikleri ve dağılımları incelenmiştir.
#
# ## Veri Görselleştirme
# Özelliklerin dağılımları ve sınıflara göre dağılımlar kutu grafikleri ile görselleştirilmiştir.
#
# ## Sonuçlar
# - Sepal ve petal özelliklerinin sınıflara göre dağılımları belirgin farklılıklar göstermektedir.
# - Özellikle petal özellikleri, sınıfları ayırt etmede daha belirgin farklar sunmaktadır.
